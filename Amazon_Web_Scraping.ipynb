# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# Connect to Website and pull in data

URL = 'https://www.amazon.com/Khadlaj-Island-Dreams-Long-Lasting-Fragrance/dp/B0FM8NS3FQ/ref=sr_1_1?crid=230LSFJ9L07XS&dib=eyJ2IjoiMSJ9.Q3mKuclkslBBiB0LqQTK5egqDMdg4weYIhaySjli5HLhluOG_20rsLVKlG9twx-na0Sn2992FMr8SehtgxV4QBrBSvEYHcx_GnyHRvWrmp04M1VrZ64dqqMJrL1TK5NFwhhqAy1Jk3NaHR7p9e7gTBO7xpouT1sbClcgIg3z1bZfu2BDNZUGtCWEEPB1lZ_YWlBMfNff6gtWrKCN0dL0wnS3dPWNK-d-jF5_Ca44GfOkdokHsBBWmyVNmZM2ExCwXj16t__gM5ePjkoyVTUMzrAsG5REWAMn3tD6rIRRVXY.vc6Ez3HeYdBX4x7KR0eKBDLnzNT0hWJsmSqiURK1wN8&dib_tag=se&keywords=khadlaj+island+dreams&qid=1777015044&sprefix=khadlaj%2Caps%2C434&sr=8-1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2= BeautifulSoup(soup1.prettify(),'html.parser')
print(soup1)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
URL = 'https://www.amazon.com/Khadlaj-Island-Dreams-Long-Lasting-Fragrance/dp/B0FM8NS3FQ/ref=sr_1_1?crid=230LSFJ9L07XS&dib=eyJ2IjoiMSJ9.Q3mKuclkslBBiB0LqQTK5egqDMdg4weYIhaySjli5HLhluOG_20rsLVKlG9twx-na0Sn2992FMr8SehtgxV4QBrBSvEYHcx_GnyHRvWrmp04M1VrZ64dqqMJrL1TK5NFwhhqAy1Jk3NaHR7p9e7gTBO7xpouT1sbClcgIg3z1bZfu2BDNZUGtCWEEPB1lZ_YWlBMfNff6gtWrKCN0dL0wnS3dPWNK-d-jF5_Ca44GfOkdokHsBBWmyVNmZM2ExCwXj16t__gM5ePjkoyVTUMzrAsG5REWAMn3tD6rIRRVXY.vc6Ez3HeYdBX4x7KR0eKBDLnzNT0hWJsmSqiURK1wN8&dib_tag=se&keywords=khadlaj+island+dreams&qid=1777015044&sprefix=khadlaj%2Caps%2C434&sr=8-1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2= BeautifulSoup(soup1.prettify(),'html.parser')

title= soup2.find(id= 'productTitle').get_text()

price= soup2.find(id= 'apex-pricetopay-accessibility-label').get_text()

description= soup2.find(id= 'productDescription').get_text()

print(title)
print(price)
print(description)
# Out:
#            Khadlaj Island Dreams – Fruity, Floral, Woody, Musky – Extrait de Parfum Long-Lasting Fragrance for Unisex, 3.4 Ounce
#
#
#                $45.50
#
#
#
#
#
#            Khadlaj Island Dreams Extrait de Parfum for Unisex is a refreshing and modern fragrance that evokes the essence of a serene island escape. It opens with the lively zest of bergamot and the warm spice of ginger, creating an invigorating start that instantly awakens the senses. At the heart lies a vibrant grapefruit accord, bringing a burst of citrusy brightness and tropical charm. The fragrance settles into a smooth, sensual base of ambroxan and musk, adding depth and long-lasting allure. Perfect for both men and women, Island Dreams is a versatile and uplifting scent ideal for everyday elegance or special occasions.

# %%
#Cleaning Data

price = price.strip()[1:]
title = title.strip()
description = description.strip()

print(title)
print(price)
print(description)
# Out:
# Khadlaj Island Dreams – Fruity, Floral, Woody, Musky – Extrait de Parfum Long-Lasting Fragrance for Unisex, 3.4 Ounce
# 45.50
# Khadlaj Island Dreams Extrait de Parfum for Unisex is a refreshing and modern fragrance that evokes the essence of a serene island escape. It opens with the lively zest of bergamot and the warm spice of ginger, creating an invigorating start that instantly awakens the senses. At the heart lies a vibrant grapefruit accord, bringing a burst of citrusy brightness and tropical charm. The fragrance settles into a smooth, sensual base of ambroxan and musk, adding depth and long-lasting allure. Perfect for both men and women, Island Dreams is a versatile and uplifting scent ideal for everyday elegance or special occasions.

# %%
import csv

header = ['Product', 'price',]
data = [title,price]

type(data)
# Out:
# list

# %%
import datetime
today = datetime.date.today()
print(today)
# Out:
# 2026-04-24

# %%
import csv

header = ['date','Product', 'price','description']
data = [today,title,price,description]

with open('Amazon Web scrap.csv','w', newline ='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shahm\Amazon Web Scrap.csv')
print(df)
# Out:
#         date                                            Product  price  \
# 0  4/24/2026  Khadlaj Island Dreams – Fruity, Floral, Woody,...   45.5
#
#                                          description
# 0  Khadlaj Island Dreams Extrait de Parfum for Un...

# %%
# Now Appending The Data 

with open('Amazon Web scrap.csv','a+', newline ='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com/Khadlaj-Island-Dreams-Long-Lasting-Fragrance/dp/B0FM8NS3FQ/ref=sr_1_1?crid=230LSFJ9L07XS&dib=eyJ2IjoiMSJ9.Q3mKuclkslBBiB0LqQTK5egqDMdg4weYIhaySjli5HLhluOG_20rsLVKlG9twx-na0Sn2992FMr8SehtgxV4QBrBSvEYHcx_GnyHRvWrmp04M1VrZ64dqqMJrL1TK5NFwhhqAy1Jk3NaHR7p9e7gTBO7xpouT1sbClcgIg3z1bZfu2BDNZUGtCWEEPB1lZ_YWlBMfNff6gtWrKCN0dL0wnS3dPWNK-d-jF5_Ca44GfOkdokHsBBWmyVNmZM2ExCwXj16t__gM5ePjkoyVTUMzrAsG5REWAMn3tD6rIRRVXY.vc6Ez3HeYdBX4x7KR0eKBDLnzNT0hWJsmSqiURK1wN8&dib_tag=se&keywords=khadlaj+island+dreams&qid=1777015044&sprefix=khadlaj%2Caps%2C434&sr=8-1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2= BeautifulSoup(soup1.prettify(),'html.parser')

    title= soup2.find(id= 'productTitle').get_text()

    price= soup2.find(id= 'apex-pricetopay-accessibility-label').get_text()

    description= soup2.find(id= 'productDescription').get_text()
    
    price = price.strip()[1:]
    title = title.strip()
    description = description.strip()
    
    import datetime
    
    today = datetime.date.today()

    print(today)
    
    import csv
    header = ['date','Product', 'price','description']
    data = [today,title,price,description]
    
    with open('Amazon Web scrap.csv','a+', newline ='', encoding='UTF8') as f:   
        writer = csv.writer(f) 
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\shahm\Amazon Web Scrap.csv')
print(df)

# %%
# Sending Email
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('shahmeershaikh336@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The perfume you want is below $38! Now is your chance to buy!"
    body = "Shahmeer, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here:https://www.amazon.com/Khadlaj-Island-Dreams-Long-Lasting-Fragrance/dp/B0FM8NS3FQ/ref=sr_1_1?crid=230LSFJ9L07XS&dib=eyJ2IjoiMSJ9.Q3mKuclkslBBiB0LqQTK5egqDMdg4weYIhaySjli5HLhluOG_20rsLVKlG9twx-na0Sn2992FMr8SehtgxV4QBrBSvEYHcx_GnyHRvWrmp04M1VrZ64dqqMJrL1TK5NFwhhqAy1Jk3NaHR7p9e7gTBO7xpouT1sbClcgIg3z1bZfu2BDNZUGtCWEEPB1lZ_YWlBMfNff6gtWrKCN0dL0wnS3dPWNK-d-jF5_Ca44GfOkdokHsBBWmyVNmZM2ExCwXj16t__gM5ePjkoyVTUMzrAsG5REWAMn3tD6rIRRVXY.vc6Ez3HeYdBX4x7KR0eKBDLnzNT0hWJsmSqiURK1wN8&dib_tag=se&keywords=khadlaj+island+dreams&qid=1777015044&sprefix=khadlaj%2Caps%2C434&sr=8-1
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'shahmeershaikh336@gmail.com',
        msg
     
    )
